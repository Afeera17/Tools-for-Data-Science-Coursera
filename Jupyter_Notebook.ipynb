# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Afeera**
#
# I am a "Software Engineer", and I desire to be a "Data Scientist".

# %% [markdown]
# *I am interested in Data Science because I have a curiosity to find hidden patterns in a data, and I like to convey my perspective in the form of some findings*

# %% [markdown]
# ### My code will have 2 variables, and it will print the outputs of various operations performed on those variables

# %%
a = 10
b = 20
c = b-a
print(c)
d = b*a
print(d)
e = b % a
print(e)

# %% [markdown]
# ### Social Media Apps
#
# 1. Instagram
# 2. Whatsapp
# 3. Snapchat
#
# ### Programming Languages
#
# * C
# - Java
# - Python
#
# ### Horizontal Rule
# -------
# ***

# %% [markdown]
# #### Languages Used in Data science
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia

# %% [markdown]
# ## Libraries Used in Data science
#
# 1. Tensorflow
# 2. keras
# 3. Numpy
# 4. Pandas
# 5. Scikit Learn

# %% [markdown]
# #### Tools Used in Data science
#
# 1. Apache Spark
# 2. MATLAB
# 3. BigML
# 4. Excel
# 5. Tableau

# %% [markdown]
# ### Introduction -
#
# * I am a Software Engineer
# * I want to become a Data Scientist
# * I am learning Python & R programming languages for DS.

# %% [markdown]
# "title": "My Jupyter Notebook",
# "authors": [
#   { "name": "Afeera" }
# ]
